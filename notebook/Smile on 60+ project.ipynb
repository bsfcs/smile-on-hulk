# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
smile = pd.read_csv('../data/SmileOn11.28.2020.csv', skiprows=2, encoding = "ISO-8859-1")
# Out:
# C:\Users\l1942\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (32,36,53,59,88,89,127,141,144,156,157,158,159) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
smile.head(2)
# Out:
#    CallReportNum              ReportVersion  LinkedToCallReportNum  \
# 0       81381827  SMILE ON 60+ Registration                    NaN
# 1       81379177  SMILE ON 60+ Registration                    NaN
#
#   CallDateAndTimeStart CallDateAndTimeEnd  CallLength  CallerNum  \
# 0     11/25/2020 16:46   11/25/2020 16:48           2    3859874
# 1     11/25/2020 15:40   11/25/2020 15:55          15    3859755
#
#    PhoneWorkerNum  WasRealCall  WasHangup  ...  \
# 0          136529          NaN        NaN  ...
# 1           82341          NaN        NaN  ...
#
#    SMILE ON 60+ Screening - Treatment Urgency  \
# 0                                         NaN
# 1                                         NaN
#
#    SMILE ON 60+ Screening - Untreated Decay  \
# 0                                       NaN
# 1                                       NaN
#
#          SMILE ON 60+ Site Information - Enroller ID  \
# 0  Matthew Walker Comprehensive Health Center Inc...
# ...

# %%
smile_small = pd.DataFrame()
smile_small['ID'] = smile['CallerNum']

# %%
smile_small.head(2)
# Out:
#         ID
# 0  3859874
# 1  3859755

# %%
smile_small.tail(2)
# Out:
#        ID
# 40030  -1
# 40031  -1

# %%
smile_small['last_screening'] = smile['SMILE ON 60+ Screening - Last Screening Date']

# %%
smile_small['care_provided'] = smile['SMILE ON 60+ Oral Care Encounter - What care was provided to the enrollee? (Select all that apply)']

# %%
smile_small['enroller_id'] = smile['SMILE ON 60+ Site Information - Enroller ID']

# %%
smile_small['plan_completed'] = smile['SMILE ON 60+ Treatment Plan - Is the treatment plan completed?']

# %%
smile_small['plan_developed'] = smile['SMILE ON 60+ Treatment Plan - Was a treatment plan developed?']

# %%
smile_small['function_restored'] = smile['SMILE ON 60+ Treatment Plan - Was the enrollee able to be restored to function (can chew) and "social six" esthetics (top front six teeth are present and disease free)']

# %%
smile_small['race'] = smile['SMILE ON 60+ Demographic Information - Race/Ethnicity']

# %%
smile_small['race'].value_counts()
# Out:
# Caucasian                            22730
# African American                     10496
# Hispanic                              1771
# Unknown                                640
# Asian                                  574
# American Indian and Alaska Native      129
# Multi-racial                           105
# Pacific Islander                         9
# Name: race, dtype: int64

# %%
smile_small.head()
# Out:
#         ID last_screening                                      care_provided  \
# 0  3859874            NaN                                                NaN
# 1  3859755            NaN                                                NaN
# 2  2518680            NaN  5650 - Add tooth to existing partial denture - 30
# 3  3231923            NaN  No Code - Denture step Mandibular: may be used...
# 4       -1     11/25/2020                                                NaN
#
#                                          enroller_id plan_completed  \
# 0  Matthew Walker Comprehensive Health Center Inc...            NaN
# 1                                                NaN            NaN
# 2          Friends in Need Health Center - Kingsport            Yes
# 3          Christ Community Health Services- Frayser            NaN
# 4                      Neighborhood Health - Lebanon            NaN
#
#   plan_developed function_restored              race
# ...

# %%
smile_small['ID'].value_counts()
# Out:
# -1          70
#  2441776    36
#  2431132    31
#  2416076    29
#  2466994    28
#             ..
#  3825101     1
#  3743280     1
#  2653820     1
#  3686036     1
#  3821558     1
# Name: ID, Length: 8708, dtype: int64

# %%
smile_small['function_restored'].value_counts()
# Out:
# No     8127
# Yes    6149
# Name: function_restored, dtype: int64

# %%
smile_small['plan_completed'].value_counts()
# Out:
# No     12431
# Yes     5104
# Name: plan_completed, dtype: int64

# %%
smile_small['enroller_id'].value_counts()
# Out:
# Interfaith Dental Clinic - Nashville                                                    5802
# Interfaith Dental Clinic - Murfreesboro                                                 3706
# Church Health Center - Memphis                                                          3581
# Matthew Walker Comprehensive Health Center Inc. - Nashville                             2516
# Interfaith Health Clinic of Knoxville - Knoxville                                       1822
# Karis Dental Clinic - Cleveland                                                         1809
# Friends in Need Health Center - Kingsport                                               1566
# Healing Hands Health Center - Bristol                                                   1346
# Keystone Dental Care Inc. - Johnson City                                                1032
# Christ Community Health Services- Hickory Hill                                           986
# ...

# %% [markdown]
# smile_demo = smile[['CallerNum','SMILE ON 60+ Demographic Information - Gender','SMILE ON 60+ Demographic Information - Household Income Level','SMILE ON 60+ Demographic Information - How did you first hear about the SMILE ON 60+ program?','SMILE ON 60+ Demographic Information - Preferred Language/Language Needed','SMILE ON 60+ Demographic Information - Race/Ethnicity','SMILE ON 60+ Demographic Information - What other assistance programs are you on?','SMILE ON 60+ Demographic Information - When is the last time you visited your dentist?','SMILE ON 60+ Demographic Information - # of People in Household','SMILE ON 60+ Demographic Information - Other Language']]

# %%
smile_med = pd.DataFrame()

# %%
smile_med['ID'] = smile['CallerNum']

# %%
smile_med['city'] = smile['CityName']

# %%
smile_med['county'] = smile['CountyName']
smile_med['zip'] = smile['PostalCode']

# %%
smile_med['YOB'] = smile['Birth Year']
smile_med['gender'] = smile['SMILE ON 60+ Demographic Information - Gender']
smile_med['race'] = smile['SMILE ON 60+ Demographic Information - Race/Ethnicity']

# %%
smile_med['last visit'] = smile['SMILE ON 60+ Demographic Information - When is the last time you visited your dentist?']

# %%
smile_med['QLgrills'] = smile['SMILE ON 60+ Base-line Oral and Conditions Questions - Have you ever felt that the appearance of your mouth and teeth affected your quality of life?']

# %%
smile_med['60+ambassadors'] = smile['SMILE ON 60+ Demographic Information - How did you first hear about the SMILE ON 60+ program?']

# %%
smile_med['enrollerID'] = smile['SMILE ON 60+ Site Information - Enroller ID']

# %%
smile_med.head(2)
# Out:
#         ID         city     county      zip   DOB gender       race  \
# 0  3859874  Springfield  Robertson  37172.0  1957   Male  Caucasian
# 1  3859755    Nashville   Davidson  37212.0  1943   Male  Caucasian
#
#      last visit   YOB QLgrills       60+ambassadors  \
# 0  3 to 5 years  1957      Yes  Dental Clinic Staff
# 1  3 to 5 years  1943       No  Dental Clinic Staff
#
#                                           enrollerID
# 0  Matthew Walker Comprehensive Health Center Inc...
# 1                                                NaN

# %%
smile_med['county'].value_counts()
# Out:
# Davidson           9299
# Shelby             7398
# Rutherford         3837
# Sullivan           2209
# Bradley            1789
#                    ...
# TN                    1
# Fulton                1
# Walker                1
# Winchester City       1
# McNairy               1
# Name: county, Length: 104, dtype: int64

# %%
smile_med['county'].head(50)
# Out:
# 0      Robertson
# 1       Davidson
# 2        Hawkins
# 3         Shelby
# 4            NaN
# 5       Sullivan
# 6         Wilson
# 7        Hawkins
# 8         Wilson
# 9         Shelby
# 10        Wilson
# 11         Lewis
# 12      Sullivan
# 13       Bradley
# 14        Shelby
# 15       Bradley
# 16       Hawkins
# 17           NaN
# 18      Davidson
# 19          Knox
# 20       Madison
# 21      Lawrence
# 22           NaN
# 23        Shelby
# 24         White
# 25        Shelby
# 26       Hawkins
# 27        Shelby
# 28        Shelby
# 29      Davidson
# 30         Lewis
# 31    Washington
# 32          Knox
# 33         Roane
# 34        Shelby
# 35       Bradley
# 36      Sullivan
# 37         Maury
# 38         Maury
# 39       Bradley
# 40         Maury
# 41    Rutherford
# 42    Williamson
# 43         Maury
# 44    Rutherford
# 45          Knox
# 46      Davidson
# 47      Davidson
# 48        Shelby
# 49        Shelby
# Name: county, dtype: object

# %%
county_count = smile_med['county'].value_counts().rename_axis('county').reset_index(name='counts')

# %%
county_count.head(50)
# Out:
#         county  counts
# 0     Davidson    9299
# 1       Shelby    7398
# 2   Rutherford    3837
# 3     Sullivan    2209
# 4      Bradley    1789
# 5         Knox    1618
# 6   Washington    1118
# 7       Sumner     859
# 8       Wilson     793
# 9   Montgomery     612
# 10  Williamson     611
# 11     Hawkins     553
# 12      Sevier     532
# 13     Bedford     476
# 14       Maury     402
# 15      Putnam     357
# 16      Blount     343
# 17      Greene     326
# 18      Carter     316
# 19   Robertson     314
# 20    Cheatham     291
# 21      Coffee     267
# 22      Cannon     256
# 23    Lawrence     245
# 24    Marshall     237
# 25     Johnson     236
# 26      Warren     206
# 27     Dickson     194
# 28       Giles     192
# 29      Grundy     184
# 30      Tipton     177
# 31     Lincoln     173
# 32      Marion     151
# 33    Franklin     139
# 34      Unicoi     128
# 35       Cocke     126
# 36       Lewis     124
# 37        Rhea     103
# 38    Hamilton      96
# ...

# %%
pd.set_option('display.max_rows', 105)
county_count.head(105)
# Out:
#               county  counts
# 0           Davidson    9299
# 1             Shelby    7398
# 2         Rutherford    3837
# 3           Sullivan    2209
# 4            Bradley    1789
# 5               Knox    1618
# 6         Washington    1118
# 7             Sumner     859
# 8             Wilson     793
# 9         Montgomery     612
# 10        Williamson     611
# 11           Hawkins     553
# 12            Sevier     532
# 13           Bedford     476
# 14             Maury     402
# 15            Putnam     357
# 16            Blount     343
# 17            Greene     326
# 18            Carter     316
# 19         Robertson     314
# 20          Cheatham     291
# 21            Coffee     267
# 22            Cannon     256
# 23          Lawrence     245
# 24          Marshall     237
# 25           Johnson     236
# 26            Warren     206
# 27           Dickson     194
# 28             Giles     192
# 29            Grundy     184
# 30            Tipton     177
# ...
