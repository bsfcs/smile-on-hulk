# %% [markdown]
# Notebook for EDA of CDC tooth loss data.
# Built by Chris Mulvey on 1 December 2020.

# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
cdc = pd.read_csv('../data/500_Cities__Local_Data_for_Better_Health__2019_release(1).csv')

# %%
cdc.head()
# Out:
#    Year StateAbbr  StateDesc   CityName GeographicLevel DataSource  \
# 0  2016        TN  Tennessee  Nashville    Census Tract      BRFSS
# 1  2016        TN  Tennessee  Nashville    Census Tract      BRFSS
# 2  2016        TN  Tennessee  Nashville    Census Tract      BRFSS
# 3  2016        TN  Tennessee    Memphis    Census Tract      BRFSS
# 4  2016        TN  Tennessee    Memphis    Census Tract      BRFSS
#
#           Category             UniqueID  \
# 0  Health Outcomes  4752006-47037013201
# 1       Prevention  4752006-47037011600
# 2       Prevention  4752006-47037015617
# 3  Health Outcomes  4748000-47157002500
# 4       Prevention  4748000-47157021010
#
#                                              Measure Data_Value_Unit  ...  \
# 0        All teeth lost among adults aged >=65 Years               %  ...
# 1  Visits to dentist or dental clinic among adult...               %  ...
# 2  Visits to dentist or dental clinic among adult...               %  ...
# 3        All teeth lost among adults aged >=65 Years               %  ...
# 4  Visits to dentist or dental clinic among adult...               %  ...
#
#   High_Confidence_Limit Data_Value_Footnote_Symbol  Data_Value_Footnote  \
# 0                  20.1                        NaN                  NaN
# 1                  70.4                        NaN                  NaN
# 2                  73.0                        NaN                  NaN
# 3                  26.2                        NaN                  NaN
# 4                  72.3                        NaN                  NaN
#
#    PopulationCount                      GeoLocation CategoryID  MeasureId  \
# 0            2,936  (36.1514089398, -86.8836263472)    HLTHOUT  TEETHLOST
# 1            4,751  (36.1834698574, -86.7113792554)    PREVENT     DENTAL
# 2            2,368  (36.1017022136, -86.6046378648)    PREVENT     DENTAL
# 3            2,877   (35.150699683, -90.0159941929)    HLTHOUT  TEETHLOST
# 4            5,227  (35.2004562979, -89.7023398896)    PREVENT     DENTAL
#
#   CityFIPS     TractFIPS Short_Question_Text
# 0  4752006  4.703701e+10          Teeth Loss
# 1  4752006  4.703701e+10        Dental Visit
# 2  4752006  4.703702e+10        Dental Visit
# 3  4748000  4.715700e+10          Teeth Loss
# 4  4748000  4.715702e+10        Dental Visit
#
# [5 rows x 24 columns]

# %%
cdc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1083 entries, 0 to 1082
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        1083 non-null   int64
#  1   StateAbbr                   1083 non-null   object
#  2   StateDesc                   1083 non-null   object
#  3   CityName                    1083 non-null   object
#  4   GeographicLevel             1083 non-null   object
#  5   DataSource                  1083 non-null   object
#  6   Category                    1083 non-null   object
#  7   UniqueID                    1083 non-null   object
#  8   Measure                     1083 non-null   object
#  9   Data_Value_Unit             1083 non-null   object
#  10  DataValueTypeID             1083 non-null   object
#  11  Data_Value_Type             1083 non-null   object
#  12  Data_Value                  1043 non-null   float64
#  13  Low_Confidence_Limit        1043 non-null   float64
#  14  High_Confidence_Limit       1043 non-null   float64
#  15  Data_Value_Footnote_Symbol  40 non-null     object
#  16  Data_Value_Footnote         40 non-null     object
#  17  PopulationCount             1083 non-null   object
#  18  GeoLocation                 1083 non-null   object
#  19  CategoryID                  1083 non-null   object
#  20  MeasureId                   1083 non-null   object
#  21  CityFIPS                    1083 non-null   int64
#  22  TractFIPS                   1059 non-null   float64
#  23  Short_Question_Text         1083 non-null   object
# dtypes: float64(4), int64(2), object(18)
# memory usage: 203.2+ KB
